# %%
# !pip install selenium
# Out:
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 47.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.7/467.7 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.0 MB/s eta 0:00:00
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# ...
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.58.0
#     Uninstalling websocket-client-0.58.0:
#       Successfully uninstalled websocket-client-0.58.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
driver = webdriver.Chrome(
        '')

driver.get('https://cl.indeed.com/jobs?q=data%20analyst&l=Santiago%20de%20Chile%2C%20Regi%C3%B3n%20Metropolitana&from=searchOnHP//')

# %%
df = pd.DataFrame({'Link':[''], 'Job Title':[''], 'Company':[''], 'Date Posted':[''], 'Location':['']})

# %%
##df = pd.DataFrame({'url':['url1' , 'url2'], 'cargo':['', ''], 'empresa':['', ''], 'fecha publicada':['', ''], 'ubic':['', '']})

# %%
df = pd.DataFrame({'url':[''], 'cargo':[''], 'empresa':[''], 'fecha publicada':[''], 'ubic':['']})

# %%
df
# Out:
#   Link Job Title Company Date Posted Location
# 0

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
boxes = soup.find_all('div', class_ ='job_seen_beacon')

# %%
print(boxes)
# Out:
# [<div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><div class="css-dekpa e37uo190"><h2 class="jobTitle css-198pbd eu4oa1w0" tabindex="-1"><a aria-label="detalles completos de Data Analyst - People Services" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="53491595c5a4e367" data-mobtk="1i1acjbccirl585f" href="/rc/clk?jk=53491595c5a4e367&amp;bb=D1H13_zLaKVCrFu8RVAgHeSnV12vGvSNFVl7BzisD_kLC5qgTPR3l8rNs_bJX7LCVMUOS3ZvaBX1NrLeryfFL-8-Uv4QD6UOBB2uSB2-hNgrXaJ54riuo-mWfaIdjt3S&amp;xkcb=SoBi67M3_qRCtZSRXR0LbzkdCdPP&amp;fccid=25b9aa55f7b71e5c&amp;vjs=3" id="job_53491595c5a4e367" role="button"><span id="jobTitle-53491595c5a4e367" title="Data Analyst - People Services">Data Analyst - People Services</span></a></h2><div class="css-1hlnck6 e37uo190"></div></div><div class="company_location css-17fky0v e37u
# ...

# %%
# Encontrar el elemento que contiene la fecha de publicación
fecha_element = soup.find('div', {'data-testid': 'myJobsStateDate'})

# Extraer el texto de la fecha
if fecha_element:
    fecha_texto = fecha_element.text.strip()  # Esto debería ser "Publicado hace 7 días"
    # Puedes procesar este texto adicionalmente para obtener la fecha en un formato deseado
    print("Fecha de publicación:", fecha_texto)
else:
    print("No se encontró la fecha de publicación en el HTML proporcionado.")
# Out:
# No se encontró la fecha de publicación en el HTML proporcionado.

# %%
# Encontrar la lista de elementos <ul>
ul_element = soup.find('ul', {'style': 'list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;'})

# Extraer todos los elementos <li> dentro de la lista <ul>
list_items = ul_element.find_all('li')

# Extraer y imprimir el texto de cada elemento <li>
for item in list_items:
    print(item.text)
# Out:
# Estudios en Ingeniería Informática, Estadística o carreras afines.
# 2+ años utilizando herramientas de base de datos (Python, Jupyter o Rstudio).

# %%
# Encontrar el elemento que contiene la ubicación
ubicacion_element = soup.find('div', {'data-testid': 'text-location'})

# Extraer el texto de la ubicación
if ubicacion_element:
    ubicacion_texto = ubicacion_element.text.strip()  # Esto debería ser "Santiago de Chile, Región Metropolitana"
    print("Ubicación:", ubicacion_texto)
else:
    print("No se encontró la ubicación en el HTML proporcionado.")
# Out:
# Ubicación: Santiago de Chile, Región Metropolitana

# %%
for i in boxes:
    link = i.find('a').get('href')
    job_title = i.find('a', class_ = 'jcs-JobTitle css-jspxzf eu4oa1w0').text
    print(job_title)
    company = i.find('span', class_ = 'css-63koeb eu4oa1w0').text
    print(company)
    location = i.find('div', {'data-testid': 'text-location'}).text
    print(location)
   # date_posted = i.find('div', {'data-testid': 'myJobsStateDate'}).text
    #print(date_posted)
    new_row = pd.DataFrame({'Link': [link], 'Job Title': [job_title],  'Company': [company], 'Date Posted': [''], 'Location': [location] })
    # Concatenar el nuevo DataFrame con el existente
    df = pd.concat([df, new_row], ignore_index=True)
# Out:
# Data Analyst - People Services
# GHD
# Santiago de Chile, Región Metropolitana
# Data Quality Analyst - Intermediate
# Equifax
# Las Condes, Región Metropolitana
# Business Data Analyst
# GASCO
# Santiago de Chile, Región Metropolitana
# Data Analyst Senior
# Betterfly
# Providencia, Región Metropolitana
# Practicante Data Analyst
# Falabella Retail Chile
# Santiago de Chile, Región Metropolitana
# Data Analyst
# CobaltoTalent
# Santiago de Chile, Región Metropolitana
# Database Support Analyst
# IQVIA
# Santiago de Chile, Región Metropolitana
# Programa de Talento STEM
# Itaú
# Las Condes, Región Metropolitana
# Accounting Analyst
# Energizer
# Santiago de Chile, Región Metropolitana
# Data Analyst
# Talentfinder
# Las Condes, Región Metropolitana
# Data Analyst II
# PagerDuty
# Santiago de Chile, Región Metropolitana
# Data Engineer
# SQM
# Las Condes, Región Metropolitana
# Business Intelligence Analyst
# Syngenta Crop Protection
# Santiago de Chile, Región Metropolitana
# ...

# %%
df
# Out:
#                                                  Link  \
# 0
# 1   /rc/clk?jk=53491595c5a4e367&bb=D1H13_zLaKVCrFu...
# 2   /rc/clk?jk=e5fcc0bd383679ff&bb=D1H13_zLaKVCrFu...
# 3   /rc/clk?jk=5227f19159d7f638&bb=D1H13_zLaKVCrFu...
# 4   /rc/clk?jk=fd0a84f74e8af91e&bb=D1H13_zLaKVCrFu...
# 5   /rc/clk?jk=ed811965f4de0fd7&bb=D1H13_zLaKVCrFu...
# 6   /rc/clk?jk=1edc33a93ce0524e&bb=D1H13_zLaKVCrFu...
# 7   /rc/clk?jk=c16ead0ae117b664&bb=D1H13_zLaKVCrFu...
# 8   /rc/clk?jk=179e8e772f56a88c&bb=D1H13_zLaKVCrFu...
# 9   /rc/clk?jk=993e4f5e0f1d80b2&bb=D1H13_zLaKVCrFu...
# 10  /rc/clk?jk=e4c96e56ce565b9e&bb=D1H13_zLaKVCrFu...
# 11  /rc/clk?jk=1863ddbf5f75b704&bb=D1H13_zLaKVCrFu...
# 12  /rc/clk?jk=ac849b48002a781d&bb=D1H13_zLaKVCrFu...
# 13  /rc/clk?jk=234d15d26bf24784&bb=D1H13_zLaKVCrFu...
# 14  /rc/clk?jk=bf06af35c705c1d3&bb=D1H13_zLaKVCrFu...
# 15  /rc/clk?jk=92ddbfb9126ad6dd&bb=D1H13_zLaKVCrFu...
# 16  /rc/clk?jk=53491595c5a4e367&bb=D1H13_zLaKVCrFu...
# ...

# %%
# Encontrar el enlace de la página siguiente
next_page_link = soup.find('a', {'data-testid': 'pagination-page-next'})

# Extraer la URL de la página siguiente
if next_page_link:
    next_page_url = next_page_link['href']
    print("URL de la página siguiente:", next_page_url)
else:
    print("No se encontró el enlace de la página siguiente en el HTML proporcionado.")
# Out:
# URL de la página siguiente: /jobs?q=data+analyst&l=Santiago+de+Chile%2C+Regi%C3%B3n+Metropolitana&start=10

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

driver = webdriver.Chrome(
        '')

driver.get('https://cl.indeed.com/jobs?q=data%20analyst&l=Santiago%20de%20Chile%2C%20Regi%C3%B3n%20Metropolitana&from=searchOnHP//')



########################################## - SCRAPING THE DATA - #############################################


df = pd.DataFrame({'Link':[''], 'Job Title':[''], 'Company':[''], 'Date Posted':[''], 'Location':['']})

while True:
        
    soup = BeautifulSoup(driver.page_source, 'lxml')
    boxes = soup.find_all('div', class_ ='job_seen_beacon')
    
for i in boxes:
    link = i.find('a').get('href')
    job_title = i.find('a', class_ = 'jcs-JobTitle css-jspxzf eu4oa1w0').text
    print(job_title)
    company = i.find('span', class_ = 'css-63koeb eu4oa1w0').text
    print(company)
    location = i.find('div', {'data-testid': 'text-location'}).text
    print(location)
   # date_posted = i.find('div', {'data-testid': 'myJobsStateDate'}).text
    #print(date_posted)
    new_row = pd.DataFrame({'Link': [link], 'Job Title': [job_title],  'Company': [company], 'Date Posted': [''], 'Location': [location] })
    # Concatenar el nuevo DataFrame con el existente
    df = pd.concat([df, new_row], ignore_index=True)
        
   # next_page = soup.find('a', {'aria-label': 'Next Page'}).get('href')
    next_page = soup.find('a', {'data-testid': 'pagination-page-next'})
    next_page = 'https://cl.indeed.com' +next_page
    driver.get(next_page)
    time.sleep(3)
    

######################################### - CLEANING THE DATA - ##########################################

    

df['Link'] = 'https://ca.indeed.com' + df['Link']

def posted(x):
    x = x.replace('PostedPosted','').strip()
    return x

df = df.iloc[1:,:]
def day(x):
    try:
        x = x.replace('days ago','').strip()
        x = x.replace('day ago','').strip()
        return float(x)
    except:
        return x

df['Date Posted'] = df['Date Posted'].apply(posted)
df['Date Posted'] = df['Date Posted'].apply(day)


################################### SEND EMAIL WITH CSV ###############################

# %%
df
